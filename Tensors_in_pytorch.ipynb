# %% [markdown]
# <a href="https://colab.research.google.com/github/kumawatmanish05/Pytorch-/blob/main/Tensors_in_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 2.9.0+cu126

# %%
if torch.cuda.is_available():
    print("GPU is available")
    print(f"Using GPU : {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available.Using CPU.")
# Out:
# GPU is available
# Using GPU : Tesla T4

# %% [markdown]
# # **Creating a tensor**
